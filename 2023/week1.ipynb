# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1) Input the data

# %%
df = pd.read_csv('data/PD2023_Wk1_Input.csv')

# %% [markdown]
# ### 2) Split the Transaction Code to extract the letters at the start of the transaction code. These identify the bank who processes the transaction (help). Rename the new field with the Bank code 'Bank'

# %%
df['Bank'] = df.loc[:,'Transaction Code'].str.split('-', n=1, expand=True)[0]

#Anhother approach using regular expression
#df['Bank'] = df['Transaction Code'].str.findall("^[A-Z]+")

# %%
df['Transaction Code'] = df.loc[:,'Transaction Code'].str.split('-', n=1, expand=True)[1]

# %% [markdown]
# ### 3) Rename the values in the Online or In-person field, Online of the 1 values and In-Person for the 2 values

# %%
df.loc[df['Online or In-Person'] == 1, 'Online or In-Person'] = "Online"
df.loc[df['Online or In-Person'] == 2, 'Online or In-Person'] = "In-Person"

# Another way, but using numpy also...

#np.where(df['Online or In-Person'] == 1, 'Online', 'In-Person')

# %% [markdown]
# ### 4) Change the date to be the day of the week

# %%
df['Transaction Date'] = df['Transaction Date'].astype("datetime64").dt.day_name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# G:\Programas\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-281-1ebdc1db994c> in <module>
# ----> 1 df['Transaction Date'] = df['Transaction Date'].astype("datetime64").dt.day_name()
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     688         elif is_datetime64_dtype(dtype):
#     689             from pandas import to_datetime
# --> 690             return astype_nansafe(to_datetime(arr).values, dtype, copy=copy)
#     691         elif is_timedelta64_dtype(dtype):
#     692             from pandas import to_timedelta
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     607             result = _convert_and_box_cache(arg, cache_array, box, errors)
#     608         else:
# --> 609             result = convert_listlike(arg, box, format)
#     610     else:
#     611         result = convert_listlike(np.array([arg]), box, format)[0]
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     300             arg, dayfirst=dayfirst, yearfirst=yearfirst,
#     301             utc=utc, errors=errors, require_iso8601=require_iso8601,
# --> 302             allow_object=True)
#     303
#     304     if tz_parsed is not None:
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1864             return values.view('i8'), tz_parsed
#    1865         except (ValueError, TypeError):
# -> 1866             raise e
#    1867
#    1868     if tz_parsed is not None:
#
# G:\Programas\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855             dayfirst=dayfirst,
#    1856             yearfirst=yearfirst,
# -> 1857             require_iso8601=require_iso8601
#    1858         )
#    1859     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1-01-01 00:00:00

# %% [markdown]
# ### 5) Different levels of detail are required in the outputs. You will need to sum up the values of the transactions in three ways (help):
#
#     1. Total Values of Transactions by each bank
#     2. Total Values by Bank, Day of the Week and Type of Transaction (Online or In-Person)
#     3. Total Values by Bank and Customer Code

# %% [markdown]
# #### 1. Total Values of Transactions by each bank

# %%
df.groupby('Bank').sum().drop('Customer Code', axis=1)

# Or...
# type(df.groupby('Bank')['Value'].sum())
# Out:
#        Value
# Bank
# DS    653940
# DSB   530489
# DTB   618238

# %% [markdown]
# #### 2. Total Values by Bank, Day of the Week and Type of Transaction (Online or In-Person)

# %%
df.groupby(['Bank','Transaction Date', 'Online or In-Person']).sum().drop('Customer Code', axis=1)
# Out:
#                                            Value
# Bank Transaction Date Online or In-Person
# DS   Friday           In-Person            50925
#                       Online               61713
#      Monday           In-Person            50810
#                       Online               34668
#      Saturday         In-Person            41141
#                       Online               64362
#      Sunday           In-Person            70291
#                       Online               40022
#      Thursday         In-Person            39805
#                       Online               11448
#      Tuesday          In-Person            42519
#                       Online               41709
#      Wednesday        In-Person            63957
#                       Online               40570
# DSB  Friday           In-Person            31640
#                       Online               30308
#      Monday           In-Person            39507
#                       Online               37895
#      Saturday         In-Person            72116
#                       Online               39699
#      Sunday           In-Person            38907
#                       Online               13701
#      Thursday         In-Person            36124
#                       Online               31552
#      Tuesday          In-Person            13564
#                       Online               44387
#      Wednesday        In-Person            33764
#                       Online               67325
# DTB  Friday           In-Person            72080
#                       Online               19467
#      Monday           In-Person            25951
#                       Online               44210
#      Saturday         In-Person            72778
#                       Online               27722
#      Sunday           In-Person            26900
#                       Online               49997
#      Thursday         In-Person            46095
#                       Online               77318
#      Tuesday          In-Person            30040
#                       Online               41652
#      Wednesday        In-Person            49833
#                       Online               34195

# %%
# Checking rows. The have to have 42
df.groupby(['Bank','Transaction Date', 'Online or In-Person'])['Value'].sum().count() == 42
# Out:
# True

# %%
df.groupby(['Bank','Customer Code']).sum()
# Out:
#                     Value
# Bank Customer Code
# DS   100000         57909
#      100001         53063
#      100002         69803
#      100003         25482
#      100004         63315
#      100005         39668
#      100006         77636
#      100007         76190
#      100008         56400
#      100009         56581
#      100010         77893
# DSB  100000         27585
#      100001         67856
#      100002         27936
#      100003         58154
#      100004         39003
#      100005         56396
#      100006         32333
#      100007         29702
#      100008         47121
#      100009         51749
#      100010         92654
# DTB  100000         77252
#      100001         60675
#      100002         48616
#      100003         84574
#      100004         44435
#      100005         37795
#      100006         41909
#      100007         29308
#      100008         69352
#      100009         52926
#      100010         71396

# %%
# The dataframe has to have 33 rows
df.groupby(['Bank','Customer Code']).sum().count() == 33
# Out:
# Value    True
# dtype: bool
